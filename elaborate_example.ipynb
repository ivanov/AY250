# %% [markdown]
# Elaborate Matplotlib Plots: An XKCD Re-enactment------------------![cat proximity](http://imgs.xkcd.com/comics/cat_proximity.png)

# %%
# %pylab inline# xkcd.com/231
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
ax = plt.gca() # gca = get current axes

# %%
x = np.linspace(0, np.pi/4,100)y = np.exp(4*x)**xintel = -y + y.max()inan = yplt.plot(x,intel)plt.plot(x,inan)

# %%
plt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")plt.legend()

# %%
plt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")plt.legend(loc='best')

# %%
#legend detourplt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")plt.legend(loc='best')plt.xlabel("HUMAN PROXIMITY TO CAT")

# %%
# everything's relative (x and y ticks)plt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")plt.legend(loc='best')plt.xlabel("HUMAN PROXIMITY TO CAT")plt.yticks([])plt.xticks([0,.8],['FAR','NEAR'])
# Out:
# ([<matplotlib.axis.XTick at 0xb3013b6c>, <matplotlib.axis.XTick at 0x9ce580c>], <a list of 2 Text xticklabel objects>)

# %%
# liberate axes! (no more 'little boxes')plt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")l = plt.legend(loc='best')plt.xlabel("HUMAN PROXIMITY TO CAT")plt.yticks([])plt.xticks([0,.8],['FAR','NEAR'])ax = plt.gca()ax.spines['top'].set_visible(False)ax.spines['right'].set_visible(False)l.draw_frame(False)

# %%
# get rid of that nervous tick, up topplt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")l = plt.legend(loc='best')plt.xlabel("HUMAN PROXIMITY TO CAT")plt.yticks([])plt.xticks([0,.8],['FAR','NEAR'])ax = plt.gca()ax.spines['top'].set_visible(False)ax.spines['right'].set_visible(False)l.draw_frame(False)ax.xaxis.tick_bottom()

# %%
# no more legendplt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")plt.xlabel("HUMAN PROXIMITY TO CAT")plt.yticks([])plt.xticks([0,.8],['FAR','NEAR'])ax = plt.gca()ax.spines['top'].set_visible(False)ax.spines['right'].set_visible(False)ax.xaxis.tick_bottom()# point out ax.transAxes vs ax.transData plt.annotate("\nINTELLIGENCE", (x[40],intel[40]), (-10,-40), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    ha='center'    )plt.annotate("\nINANITY OF\nSTATEMENTS", (x[60],inan[60]), (10,-45), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    )

# %%
l, = plt.plot(0,1)plt.annotate("YOU'RE A KITTY!", xy=(0, -1),  xycoords='data',                xytext=(-30, 20), textcoords='offset points',                size=10,                va='center',                bbox=dict(boxstyle="round", fc=(1.0, 1.0, 1.0), ec=(0, 0, 0)),                arrowprops=dict(arrowstyle="wedge,tail_width=1.",                                fc=(1.0, 1.0, 1.0), ec=(0, 0, 0),                                patchA=None,                                patchB=None,                                relpos=(0.5, 0.4),                                connectionstyle="arc3,rad=-0.0"),                )plt.xlim(-2,2)plt.ylim(-2,2)
# Out:
# (-2, 2)

# %%
# !wget http://imgs.xkcd.com/comics/cat_proximity.png
# Out:
# --2012-01-29 21:46:05--  http://imgs.xkcd.com/comics/cat_proximity.pngResolving imgs.xkcd.com...
# 208.122.62.226Connecting to imgs.xkcd.com|208.122.62.226|:80... connected.HTTP request sent, awaiting response... 200 OKLength: 16573 (16K) [image/png]Saving to: `cat_proximity.png' 0% [                                       ] 0           --.-K/s
# 100%[======================================>] 16,573      --.-K/s   in 0.05s
# 2012-01-29 21:46:05 (312 KB/s) - `cat_proximity.png' saved [16573/16573]

# %%
im = plt.imread('cat_proximity.png')

# %%
plt.imshow(im[0:40,0:40])

# %%
plt.gray()plt.imshow(im[0:100,0:100])

# %%
ax_im = plt.imshow(im[-100:-20,40:100])

# %%
fig = plt.gcf()fig.subplotpars.bottom=.35ax= plt.subplot(1,1,1) #matlab-style initializationax2 = fig.add_axes([0.0, 0.0, .3, 0.3])ax_im = plt.imshow(im[-100:-20,40:100])ax3 = fig.add_axes([0.3, .0, .3, 0.3])ax_im = plt.imshow(im[-100:-20:,180:240])ax4 = fig.add_axes([0.6, .0, .45, 0.3])ax_im = plt.imshow(im[-100:-20:,320:420])plt.annotate("YOU'RE A KITTY!", xy=(30, 10),  xycoords='data',                xytext=(-30, 20), textcoords='offset points',                size=10,                va='center',                bbox=dict(boxstyle="round", fc=(1.0, 1.0, 1.0), ec=(0, 0, 0)),                arrowprops=dict(arrowstyle="wedge,tail_width=1.",                                fc=(1.0, 1.0, 1.0), ec=(0, 0, 0),                                patchA=None,                                patchB=None,                                relpos=(0.5, 0.4),                                connectionstyle="arc3,rad=-0.0"),                )

# %%
# putting it all together# no more legendfig = plt.gcf()fig.subplotpars.bottom=.35ax= plt.subplot(1,1,1) #matlab-style initializationplt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")plt.xlabel("HUMAN PROXIMITY TO CAT")plt.yticks([])plt.xticks([0,.8],['FAR','NEAR'])ax = plt.gca()ax.spines['top'].set_visible(False)ax.spines['right'].set_visible(False)ax.xaxis.tick_bottom()# point out ax.transAxes vs ax.transData plt.annotate("\nINTELLIGENCE", (x[40],intel[40]), (-10,-40), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    ha='center'    )plt.annotate("\nINANITY OF\nSTATEMENTS", (x[60],inan[60]), (10,-45), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    )ax2 = fig.add_axes([0.0, 0.0, .3, 0.3])ax_im = plt.imshow(im[-100:-20,40:100])ax3 = fig.add_axes([0.3, .0, .3, 0.3])ax_im = plt.imshow(im[-100:-20:,180:240])ax4 = fig.add_axes([0.6, .0, .45, 0.3])ax_im = plt.imshow(im[-100:-20:,320:420])plt.annotate("YOU'RE A KITTY!", xy=(30, 10),  xycoords='data',                xytext=(-30, 20), textcoords='offset points',                size=10,                va='center',                bbox=dict(boxstyle="round", fc=(1.0, 1.0, 1.0), ec=(0, 0, 0)),                arrowprops=dict(arrowstyle="wedge,tail_width=1.",                                fc=(1.0, 1.0, 1.0), ec=(0, 0, 0),                                patchA=None,                                patchB=None,                                relpos=(0.5, 0.4),                                connectionstyle="arc3,rad=-0.0"),                )

# %%
# putting it all together# no more legendfig = plt.gcf()fig.subplotpars.bottom=.35ax= plt.subplot(1,1,1) #matlab-style initializationplt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")plt.xlabel("HUMAN PROXIMITY TO CAT")plt.yticks([])plt.xticks([0,.8],['FAR','NEAR'])ax = plt.gca()ax.spines['top'].set_visible(False)ax.spines['right'].set_visible(False)ax.xaxis.tick_bottom()# point out ax.transAxes vs ax.transData plt.annotate("\nINTELLIGENCE", (x[40],intel[40]), (-10,-40), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    ha='center'    )plt.annotate("\nINANITY OF\nSTATEMENTS", (x[60],inan[60]), (10,-45), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    )ax2 = fig.add_axes([0.0, 0.0, .3, 0.3])ax_im = plt.imshow(im[-100:-20,40:100])ax3 = fig.add_axes([0.3, .0, .3, 0.3])ax_im = plt.imshow(im[-100:-20:,180:240])ax4 = fig.add_axes([0.6, .0, .45, 0.3])ax_im = plt.imshow(im[-100:-20:,320:420])plt.annotate("YOU'RE A KITTY!", xy=(30, 10),  xycoords='data',                xytext=(-30, 20), textcoords='offset points',                size=10,                va='center',                bbox=dict(boxstyle="round", fc=(1.0, 1.0, 1.0), ec=(0, 0, 0)),                arrowprops=dict(arrowstyle="wedge,tail_width=1.",                                fc=(1.0, 1.0, 1.0), ec=(0, 0, 0),                                patchA=None,                                patchB=None,                                relpos=(0.5, 0.4),                                connectionstyle="arc3,rad=-0.0"),                )

# %%
def cleanup_axes(ax):    ax.set_frame_on(False)    ax.set_yticks([])    ax.set_xticks([])

# %%
# putting it all together# no more legendfig = plt.figure(figsize=(6,6))fig.subplotpars.bottom=.35ax= plt.subplot(1,1,1) #matlab-style initializationplt.plot(x,intel, label="INTELLIGENCE")plt.plot(x,inan, label="INANITY OF STATEMENTS")plt.xlabel("HUMAN PROXIMITY TO CAT")plt.yticks([])plt.xticks([0,.8],['FAR','NEAR'])ax = plt.gca()ax.spines['top'].set_visible(False)ax.spines['right'].set_visible(False)ax.xaxis.tick_bottom()# point out ax.transAxes vs ax.transData plt.annotate("\nINTELLIGENCE", (x[40],intel[40]), (-10,-40), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    ha='center'    )plt.annotate("\nINANITY OF\nSTATEMENTS", (x[60],inan[60]), (10,-45), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    )ax2 = fig.add_axes([0.0, 0.0, .3, 0.25])ax_im = plt.imshow(im[-100:-20,40:100])ax3 = fig.add_axes([0.3, .0, .3, 0.25])ax_im = plt.imshow(im[-100:-20:,180:240])ax4 = fig.add_axes([0.6, .0, .45, 0.25])ax_im = plt.imshow(im[-100:-20:,320:420])plt.annotate("YOU'RE A KITTY!", xy=(30, 10),  xycoords='data',                xytext=(-30, 20), textcoords='offset points',                size=10,                va='center',                bbox=dict(boxstyle="round", fc=(1.0, 1.0, 1.0), ec=(0, 0, 0)),                arrowprops=dict(arrowstyle="wedge,tail_width=1.",                                fc=(1.0, 1.0, 1.0), ec=(0, 0, 0),                                patchA=None,                                patchB=None,                                relpos=(0.5, 0.4),                                connectionstyle="arc3,rad=-0.0"),                )[cleanup_axes(ax) for ax in ax2, ax3, ax4]
# Out:
# [None, None, None]

# %%
# TODO: I shold redo the above images with plt.figimage() - see %loadpy http://matplotlib.sourceforge.net/mpl_examples/pylab_examples/figimage_demo.py# but i think IPython clips them out

# %%
"""This illustrates placing images directly in the figure, with no axes."""import numpy as npimport matplotlibimport matplotlib.cm as cmimport matplotlib.pyplot as pltfig = plt.figure()Z = np.arange(10000.0)Z.shape = 100,100Z[:,50:] = 1.im1 = plt.figimage(Z, xo=50, yo=0, cmap=cm.jet, origin='lower')im2 = plt.figimage(Z, xo=100, yo=100, alpha=.8, cmap=cm.jet, origin='lower')plt.show()

# %%
"""This illustrates placing images directly in the figure, with no axes."""import numpy as npimport matplotlibimport matplotlib.cm as cmimport matplotlib.pyplot as pltfig = plt.figure()Z = np.arange(10000.0)Z.shape = 100,100Z[:,50:] = 1.im1 = plt.figimage(Z, xo=50, yo=0, cmap=cm.jet, origin='lower')im2 = plt.figimage(Z, xo=100, yo=100, alpha=.8, cmap=cm.jet, origin='lower')plt.show()

# %%
# TODO: # - mention or demonstrate twinx(), since intelligene and inanity are of different units# - sharex and sharey that can be passed to subplot/subplots

# %%
# scatter plot point of no returnplt.plot(x,intel)plt.plot(x,inan)plt.xlabel("HUMAN PROXIMITY TO CAT")plt.yticks([])plt.xticks([0,.8],['FAR','NEAR'])ax = plt.gca()ax.spines['top'].set_visible(False)ax.spines['right'].set_visible(False)ax.xaxis.tick_bottom()# point out ax.transAxes vs ax.transData plt.annotate("\nINTELLIGENCE", (x[40],intel[40]), (-10,-40), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    ha='center'    )plt.annotate("\nINANITY OF\nSTATEMENTS", (x[60],inan[60]), (10,-45), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    )plt.scatter(x[:51:10],intel[:51:10],c='r', marker='*',s=150, label='Smart enough to save yourself')plt.axvline(x[50], color='r', linestyle='--', label='point of no return')plt.legend(loc='best')

# %%
# scatter plot point of no returnplt.plot(x,intel)plt.plot(x,inan)plt.xlabel("HUMAN PROXIMITY TO CAT")plt.yticks([])plt.xticks([0,.8],['FAR','NEAR'])ax = plt.gca()ax.spines['top'].set_visible(False)ax.spines['right'].set_visible(False)ax.xaxis.tick_bottom()# point out ax.transAxes vs ax.transData plt.annotate("\nINTELLIGENCE", (x[40],intel[40]), (-10,-40), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    ha='center'    )plt.annotate("\nINANITY OF\nSTATEMENTS", (x[60],inan[60]), (10,-45), textcoords='offset points',    arrowprops=dict(width=1.0, headwidth=1.0, shrink=0),    )plt.scatter(x[:51:10],intel[:51:10],c='r', marker='*',s=150, label='Smart enough to save yourself')plt.axvline(x[50], color='r', linestyle='--', label='point of no return')plt.axvspan(x[80],x[-1], color='r', label='Toxoplasmosis danger zone!', alpha=.1)plt.legend(loc='best')
